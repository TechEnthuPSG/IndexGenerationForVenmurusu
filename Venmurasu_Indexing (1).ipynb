# %% [markdown]
# #Installing and Importing

# %%
# !pip install xmltodict
# !pip install beautifulsoup4
# !pip install requests
# !pip install pystemmer
# !pip install gdown
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: pystemmer in /usr/local/lib/python3.7/dist-packages (2.0.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.4.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.62.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --id 1YSyGX_oS0zusjv9Mw8ub0ZdUC--18kvo 
# !gdown --id 10xmDYwtcjfNCvPLIt9bHaPbMQTAU2rM9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YSyGX_oS0zusjv9Mw8ub0ZdUC--18kvo
# To: /content/tokens.json
# 100% 39.4M/39.4M [00:00<00:00, 179MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10xmDYwtcjfNCvPLIt9bHaPbMQTAU2rM9
# To: /content/array.json
# 100% 190M/190M [00:02<00:00, 87.6MB/s]

# %%
from bs4 import BeautifulSoup
import requests
import xmltodict
import json
import re
import os
import os.path
import urllib.request
from tensorflow.keras.preprocessing.text import Tokenizer
import Stemmer
import pandas as pd

# %% [markdown]
# # Functions declaration

# %%
def getLinks():
  r = requests.get("https://venmurasu.in/sitemap.xml")
  xml = r.text
  o = xmltodict.parse(xml)
  obj = json.loads(json.dumps(o))
  arr = []

  for i in obj["urlset"]["url"]:
    arr.append(i["loc"])

  arr.sort()
  return arr

# %%
def normalize(txt):
  regex = r"[^\u0b80-\u0bff]"
  return re.sub(regex," ",txt)

# %%
def scrapeSite(url):
  html = urllib.request.urlopen(url)
  htmlParse = BeautifulSoup(html, 'html.parser')
  arr = []
  for para in htmlParse.find_all("p"):
    arr.append(normalize(para.get_text()))
  #print(arr)
  return arr

# %%
def tokenize(arr):
  tokenizer1 = Tokenizer(num_words=10**9)
  tokenizer1.fit_on_texts(arr)
  word_index = tokenizer1.word_index
  return word_index

# %%
def scrapeAllSites():

  if os.path.exists("array.json"):
    with open("array.json") as f:
      json_object = json.load(f)
      return json_object["arr"]

  arr = []
  siteContent = {}
  n = 0
  err_sites = []
  links = getLinks()
  linksSize = len(links)
  for i in links:
    n += 1
    try:
      cont = scrapeSite(i)
      arr.extend(cont)
    except:
      err_sites.append(i)
    print("\r\b\b\b\b\b\b\b\b\b\b\b\b\b\b\b\b\b\b\b{}/{}".format(n, linksSize))
  print("Error sites : ", err_sites)
  
  with open("array.json", "w") as f:
    d = {
        "arr" : arr
    }
    json_object = json.dumps(d, indent = 2)
    f.write(json_object)
  
  return arr

# %%
def tokenizeAll(arr):

  if os.path.exists("tokens.json"):
    with open("tokens.json") as f:
      json_object = json.load(f)
    return json_object

  d = dict(tokenize(arr))
  with open("tokens.json","w") as f:
    json.dump(d, f)
  return d

# %% [markdown]
# # Testing

# %%
arr = getLinks()
print(len(arr), "pages")
# Out:
# 1936 pages

# %%
temp = scrapeSite(arr[-20])
#print(arr[-20], len(temp), *temp, sep="\n\n")

# %%
temp_d = tokenize(temp)
print(list(temp_d))
# Out:
# ['அவர்களின்', 'அவர்கள்', 'அருணர்', 'கொண்ட', 'அவர்', 'என்னும்', 'தங்கள்', 'என்று', 'முதல்', 'என', 'எழுந்த', 'என்றனர்', 'நாகர்கள்', 'அது', 'அமைந்த', 'அடுக்கில்', 'பதினெட்டு', 'இந்திரன்', 'தன்', 'இருந்து', 'பிறர்', 'வாசுகியின்', 'வழிபட்டனர்', 'மட்டுமே', 'வாசுகியை', 'மூத்தோர்', 'சூடி', 'எழுந்து', 'அமைந்திருந்தது', 'நாகங்கள்', 'நூற்றெட்டு', 'சென்று', 'கொண்டவர்கள்', 'வாழ்ந்தனர்', 'நடுவே', 'இந்திரனுக்கு', 'நான்', 'நாகங்களின்', 'குலம்', 'இருந்த', 'நாகர்களின்', 'மைந்தர்', 'குலங்கள்', 'காடுகளில்', 'ஏழு', 'இருந்தது', 'கீழே', 'விழிகளும்', 'அமர்ந்த', 'கண்டனர்', 'தெய்வமென', 'மேல்', 'நின்று', 'குருதியில்', 'செல்ல', 'குடிநடுவே', 'அவர்களுக்கு', 'அமர்ந்து', 'இது', 'அவன்', 'இளையோரே', 'இப்புவி', 'பைரவர்', 'எனக்கு', 'செறிந்த', 'ஆண்டது', 'வாசுகி', 'அரியணை', 'சரஸ்வதியின்', 'மானுடர்', 'நாகர்குலத்து', 'ஆன', 'நாகபட', 'எழுந்தது', 'நந்தவாசுகியின்', 'சுப்ரமை', 'தட்ச', 'கௌரவ்ய', 'மானசன்', 'ஆகிய', 'மாமன்னர்களின்', 'நின்றது', 'அவர்களுக்கே', 'அவி', 'படைக்கப்பட்டது', 'நின்ற', 'ஓங்கி', 'அவை', 'கொண்டவை', 'அமைந்திருந்தன', 'தேவர்களுக்கு', 'படகுகளில்', 'முடிசூடி', 'என்றே', 'அழைத்தனர்', 'பெருஞ்சிலை', 'உச்சியில்', 'நிறுவப்பட்டிருந்தது', 'விரித்து', 'கண்டு', 'வழியாக', 'ஓயாது', 'இருந்தார்', 'நாளும்', 'தட்சகுலத்தின்', 'தலைநகரமான', 'அவற்றின்', 'ஆனது', 'அந்நகர்', 'பிற', 'சென்றனர்', 'பறக்கும்', 'தொலைப்பாடகர்', 'வந்த', 'மஹாஹனு', 'அரசர்கள்', 'நாகசிலையை', 'மைந்தரான', 'பன்னிரு', 'மூதாதை', 'பூசி', 'வரையப்பட்ட', 'வெண்முகில்', 'எனவே', 'கைகளில்', 'அப்பால்', 'நிலம்', 'அரசர்களால்', 'தோறும்', 'உடலும்', 'நின்றிருந்தது', 'இருந்தான்', 'திரும்பி', 'கோதை', 'வாழ்ந்த', 'நாகன்', 'அவற்றை', 'பத்மினியின்', 'ஒரு', 'மின்னல்', 'ஆணை', 'நச்சுநா', 'வாழும்', 'மூவேந்தரும்', 'அவர்களிடம்', 'வந்து', 'பிரிந்து', 'கடல்நாகர்கள்', 'இறங்கி', 'படைத்து', 'இப்புவியில்', 'ஏதுமில்லை', 'அதை', 'ஐங்குலத்து', 'தட்சசிலை', 'இளையவர்', 'தன்னை', 'தான்', 'ஒவ்வொருநாளும்', 'உன்னை', 'மேலும்', 'என்றார்', 'கூடாது', 'இடியோசை', 'பகுதி', 'எட்டு', 'நூறிதழ்', 'நகர்', 'அழிவிலா', 'தொல்கதையை', 'அறிக', 'ஏழுசிந்துக்களின்', 'படுகைகளிலும்', 'கங்கைவெளியிலும்', 'பெருங்காடுகளை', 'இருண்ட', 'பாதாளங்களின்', 'தலைவனாகிய', 'மூதாதையாகக்', 'மண்ணில்', 'பெருகி', 'தங்களுக்கென்றொரு', 'அரசை', 'அமைத்தபோது', 'உருவான', 'மண்மறைந்த', 'அறியும்', 'ஊற்றுமுகத்தில்', 'தொல்நிலமாகிய', 'நாகோத்ஃபேதத்தில்', 'கொண்டுவரப்பட்ட', 'அத்திமரக்கிளையை', 'நட்டு', 'அதனடியில்', 'போடப்பட்ட', 'கருங்கல்', 'பீடத்தில்', 'முதலரசர்', 'பன்னிருவர்', 'கைப்பிடித்து', 'கொண்டுசென்று', 'அமரச்செய்து', 'செம்மலர்', 'தூவி', 'அரியிட்டு', 'ஆழ்நீர்', 'தெளித்து', 'வாழ்த்தினர்', 'ஈச்சையோலையால்', 'மணிமுடியைச்', 'நாகர்குலத்தின்', 'அரசராக', 'ஆக்கினர்', 'நந்தரிலிருந்து', 'வாசுகிப்பெருங்குலம்', 'பேரரசர்', 'மகள்களான', 'மாலினி', 'பத்மினி', 'மண்டனை', 'ஆகியோரின்', 'வயிற்றில்', 'பிறநான்கு', 'பிறந்தன', 'சுப்ரமையின்', 'மைந்தரிலிருந்து', 'தட்சனை', 'முதல்தெய்வமாகக்', 'தோன்றியது', 'மாலினியில்', 'ஐராவதகுலமும்', 'பத்மினியில்', 'குலமும்', 'மண்டனையில்', 'திருதராஷ்டிரகுலமும்', 'உருவாயின', 'கொடிவழி', 'கோடிசன்', 'பூர்ணன்', 'சலன்', 'பாலன்', 'ஹலீமகன்', 'காலவேகன்', 'பிரகாலனன்', 'ஹிரண்யபாகு', 'சரணன்', 'கக்ஷகன்', 'காலந்தகன்', 'நிரைகொண்ட', 'பெருமையுடையது', 'சொல்', 'மண்சென்றபின்', 'மலையுச்சிகளில்', 'கல்', 'மன்றுகளில்', 'என்றும்', 'கேள்வி', 'அளிக்கப்பட்டது', 'நாகவேள்விகளில்', 'கங்கைக்', 'கரையில்', 'கான்நகரான', 'பிலக்ஷசிலை', 'கங்கைப்பெருக்கில்', 'நிழல்வீழ்த்தி', 'நாகபேரம்', 'மலைமேல்', 'அடுக்குகளாக', 'அடுக்கைச்சுற்றி', 'உயர்ந்து', 'முகில்சூடி', 'தேவதாருமரங்களை', 'இணைத்துக்கட்டிய', 'உயிர்மரக்கோட்டை', 'அம்மரங்களின்', 'புதர்களில்', 'நச்சுப்பல்', 'வாழ்ந்தன', 'உறங்காவிழிகளும்', 'அணையாச்சீற்றமும்', 'இரண்டாவது', 'படைவீரர்களும்', 'மூன்றாவது', 'நாகவேடர்களும்', 'நான்காவது', 'படைத்தலைவர்களும்', 'ஐந்தாவது', 'குலப்பாடகர்களும்', 'இருந்தனர்', 'ஆறாவது', 'வாசுகிக்', 'குலமூத்தார்', 'இல்லங்களும்', 'ஏழாவது', 'அரண்மனையும்', 'உப்பரிகைகளும்', 'குவைமாடங்களும்', 'அம்மாளிகையின்மேல்', 'வாசுகிகுலத்தின்', 'ஏழுதலைநாக', 'முத்திரை', 'கொடி', 'பறந்தது', 'விண்ணுலாவிய', 'வந்தமர்ந்து', 'விடாய்குளிர்க', 'அழைப்பாகத்', 'திகழ்ந்தது', 'செந்நிறமும்', 'பச்சைநிற', 'வாசுகிகுலத்தவர்', 'நாகர்களில்', 'உயரமானவர்கள்', 'வில்லுடன்', 'நதிகளில்செல்லும்', 'திறைகொண்டு', 'அரசுக்கருவூலத்தை', 'நிற ...

# %% [markdown]
# # Final Indexing

# %%
arr = scrapeAllSites()

# %%
word_index = tokenizeAll(arr)
#print(word_index)

# %%
#list(word_index)

# %%
len(word_index)
# Out:
# 449239

# %% [markdown]
# #Stemming using PyStemmer

# %%
coll = set()
n = len(word_index)
i = 0
stemmer = Stemmer.Stemmer('tamil')
for word in list(word_index):
  i += 1
  print("\r\b\b\b\b\b\b\b{:.3f}% {}/{}".format(i*100/n,i,n), end="")
  coll.add(stemmer.stemWord(word))
# Out:
# 100.000% 449239/449239

# %%
len(coll)
# Out:
# 192916

# %%
coll2 = set()
n = len(coll)
i = 0
for word in list(coll):
  i += 1
  print("\r\b\b\b\b\b\b\b{:.3f}% {}/{}".format(i*100/n,i,n), end="")
  coll2.add(stemmer.stemWord(word))
# Out:
# 100.000% 192916/192916

# %%
len(coll2)
# Out:
# 162202

# %%
print(tuple(coll2)[:15])
# Out:
# ('', 'முன்னெழ்', 'ஊர்நாவு', 'இணைசெங்கழுகு', 'பாடிவீடொன்று', 'அறைபர', 'சிறுபாதைகளினூ', 'காளவதி', 'வந்துகிட', 'முகம்பெருகு', 'பின்னகரும்பொருட்டு', 'உடல்கள்நடு', 'படிகளிலிறங்கி', 'இலக்கெனக்கொண்', 'நோக்குணர்வு')

# %%
stemmer = Stemmer.Stemmer('tamil')
for word in list(word_index)[50:100]:
  print(word," --> ",stemmer.stemWord(word))
# Out:
# பின்னர்  -->  பின்
# நின்று  -->  ந்
# தங்கள்  -->  தங்
# அவர்களின்  -->  அவர்
# உங்கள்  -->
# இன்று  -->  இன்று
# உள்ளே  -->  உள்
# அங்கு  -->  கு
# பீமன்  -->  பீமன்
# அல்ல  -->  அல்ல
# மேல்  -->  மேல்
# நம்  -->  நம்
# வெளியே  -->  வெளி
# ஏன்  -->  ஏன்
# முன்  -->  முன்
# சொன்னார்  -->  சொன்
# அப்பால்  -->  பால்
# இந்த  -->  இ
# எனக்கு  -->  என
# இங்கே  -->  கே
# சொல்  -->  சொல்
# போல  -->  போல
# அவர்களை  -->  அவர்
# இருந்து  -->  இரு
# கொண்டு  -->  கொண்டு
# துரியோதனன்  -->  துரியோ
# அவளை  -->  அவளை
# யாதவர்  -->  யாத
# வந்த  -->  வ
# முகம்  -->  முகம்
# என்றும்  -->  எல்
# சற்று  -->  சற்று
# கொண்ட  -->  கொண்ட
# இருந்தது  -->  இரு
# ஓர்  -->  ஓர்
# அரசே  -->  அரசே
# அரசி  -->  அரசி
# என்னும்  -->  என்
# பெரிய  -->  பெரி
# பின்  -->  பின்
# மட்டும்  -->  மடு
# எழுந்த  -->  எழு
# தோன்றியது  -->  தோன்றி
# தன்னை  -->  தன்
# அமர்ந்து  -->  அமர்
# உள்ளம்  -->  உள்ளம்
# எடுத்து  -->  எடு
# அத்தனை  -->  தனை
# இனி  -->  இனி
# பின்னால்  -->  பின்

# %%
stemmer = Stemmer.Stemmer('tamil')
for word in list(word_index)[:50]:
  print(word," --> ",stemmer.stemWord(word))
# Out:
# என்று  -->  என்று
# என்றான்  -->  எல்
# அவன்  -->  அவன்
# நான்  -->  நான்
# என்றார்  -->  எல்
# அவர்  -->  அவர்
# என  -->  என
# அவள்  -->  அவள்
# அது  -->  அது
# என்  -->  என்
# ஒரு  -->  ஒரு
# என்றாள்  -->  எல்
# தன்  -->  தன்
# அதை  -->  அதை
# அவர்கள்  -->  அவர்
# ஆம்  -->  ஆம்
# ஆனால்  -->  ஆன்
# நோக்கி  -->  நோக்கி
# வந்து  -->  வந்
# என்ன  -->  என்ன
# சென்று  -->  ச்
# எழுந்து  -->  எழு
# நீ  -->  நீ
# இல்லை  -->  இல்
# அந்த  -->  அ
# மீண்டும்  -->  மீண்
# நாம்  -->  நாம்
# அவனை  -->  அவனை
# அதன்  -->  அதன்
# அவை  -->  அவை
# இங்கு  -->  கு
# இது  -->  இது
# அங்கே  -->  கே
# மட்டுமே  -->  மடு
# இளைய  -->  இளை
# நீங்கள்  -->  நீங்
# மேலும்  -->  மேல்
# அர்ஜுனன்  -->  அர்ஜு
# திரும்பி  -->  திரும்
# உடல்  -->  உடல்
# என்னை  -->  என்
# மெல்ல  -->  மெல்ல
# ஒவ்வொரு  -->  ஒவ்வொரு
# இரு  -->  இரு
# சொன்னான்  -->  சொன்
# ஒன்று  -->  ஒன்று
# உன்  -->  உன்
# அருகே  -->  அர்
# கர்ணன்  -->  கர்ணன்
# அவரை  -->  அவரை

# %%
# print(Stemmer.algorithms())
# word = "அவனும்"
# word = "அவனா"
# word = "அவனோ"
# word = "அவன்"
# word = "மரங்கள்"
# word = "அரசனிடம்"
# word = "அவளை"
# word = "மரத்தை"
# word = "செய்வேன்"
# word = "பாடினேன்"
# word = "செய்வேன்"
# word = "சகுனி"
# word = "கொண்டிருக்கிறாள்"
# word = "படைத்து"
# word = "அடைந்து"
# word = "அரசனும்"
# word = "அவர்களின்" 
# word = "அவனில்லாத"
# word = "அமைந்த"
# word = "என்னும்"
# word = "இருந்து"
# word = "என்று"

# %% [markdown]
# # Snowball from Scratch

# %%
# !wget https://github.com/rdamodharan/tamil-stemmer/blob/master/tamil-stem_Unicode.sbl tamil.sbl
# Out:
# --2022-02-01 07:28:29--  https://github.com/rdamodharan/tamil-stemmer/blob/master/tamil-stem_Unicode.sbl
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tamil-stem_Unicode.sbl.1’
#
# tamil-stem_Unicode.     [ <=>                ] 262.22K  --.-KB/s    in 0.05s
#
# 2022-02-01 07:28:29 (5.33 MB/s) - ‘tamil-stem_Unicode.sbl.1’ saved [268513]
#
# --2022-02-01 07:28:29--  http://tamil.sbl/
# Resolving tamil.sbl (tamil.sbl)... failed: Name or service not known.
# wget: unable to resolve host address ‘tamil.sbl’
# FINISHED --2022-02-01 07:28:29--
# Total wall clock time: 0.4s
# Downloaded: 1 files, 262K in 0.05s (5.33 MB/s)

# %%
# !pip install snowballstemmer
import snowballstemmer
stemmer = Stemmer.Stemmer('tamil')
#print(stemmer.algorithms())
# Out:
# Requirement already satisfied: snowballstemmer in /usr/local/lib/python3.7/dist-packages (2.2.0)

# %% [markdown]
# # Custom Stemming Function(s)

# %% [markdown]
# **Reference PDF : [*here*](http://www.ijcset.com/docs/IJCSET17-08-06-023.pdf)**

# %%
def hasQuestionSuffix(word):
  return (word[-1] in ["ா", "ே", "ோ"])

def fixQuestionSuffix(word):
  return word[:-1] + "்" 

def hasConjuctionSuffix(word):
  return (word[-3:] == "ும்")

def fixConjuctionSuffix(word):
  return word[:-3] + "்" 
  #return word[:-2]

def hasPluralSuffix(word):
  return (word[-5:] == "ங்கள்") or (word[-3:] == "கள்") or word[-4:] == "றனர்" or word[-3:] == "னர்" 

def fixPluralSuffix(word):
  if word[-5:] == "ங்கள்":
    return word[:-5] + "ம்"
  elif word[-3:] == "கள்":
    return word[:-3]
  elif word[-4:] == "றனர்":
    return (word[:-3]+ "ு")
  elif word[-3:] == "னர்":
    return word[:-3]

#implement from here

def hasImperativeSuffix(word):
   return (word[-1] in ["ி"])

def fixImperativeSuffix(word):
  #logic changed here
  #return word[:-1]
  return word[:-2]

def hasTenseSuffix(word):
    return (word[-6:] == "கின்றன") or (word[-3:] in ["ேன்"]) or (word[-16:-6]=="கொண்டிருக்")

def fixTenseSuffix(word):
  if (word[-4:]=="வேன்"):  #for future tense
     return word[:-4]
  if (word[-3:] in ["ேன்"]):
    return word[:-5] + "ு"
  if (word[-6:] == "கின்றன"):  # present
     return word[:-6]
  if(word[-16:-6]=="கொண்டிருக்"):
     return word[:-18]
  

def hasCommonWordSuffix(word):
  return  "ில்லாத" in word 

def fixCommonWordSuffix(word):
  return word[:-6]+ "்"

#வேற்றுமை உருப்புகள்
def hasCaseSuffix(word):
  return (word[-4:-2] == word[-2:]) or (word[-6:] in ["த்தில்"]) or (word[-4:] in ["ிடம்", "த்த்"]) or (word[-1]=='ை') or (word[-2:] in ["த்","ந்"]) or  (word[-4:] in ["த்து","ந்து","ந்த"] or word[-3:] in ["ந்த"]) or (word[-3:] == "ின்") or (word[-1:]== "ு")

#வேற்றுமை உருப்புகள்
def fixCaseSuffix(word):
  if(word[-4:-2] == word[-2:]):
    return word[:-2]
  if(word[-1:]== "ு"):
    if(word[-2]==word[-3]):
        return word[:-3]
    else:
        return word[:-2]
  if(word[-6:] in ["த்தில்"]):
    return word[:-6]+"ம்"
  if (word[-4:] in ["த்து","ந்து","ந்த"] or word[-3:] in ["ந்த"]):
    if(word[-3:] in ["ந்த"]):
      return word[:-3]
    return word[:-4]
  if word[-4:] == "த்த்":
    return word[:-4] + "ம்"
  if(word[-4:] == "ிடம்"):
    return word[:-4]+'்'
  if(word[-1]=='ை'):
    return word[:-1]+'்'
  if(word[-2:] in ["த்","ந்"]):  # to remove last extra mei eluthu
    return word[:-2]
  if word[-3:] == "ின்":
    return word[:-3] + '்'
  return word

# %%
def stem(word):

  iteration = 0
  temp = word.replace('ஂ', '்')
  
  while temp and len(temp) > 4:

    iteration += 1
    # print("Beginning of iteration {} : {}".format(iteration, temp))

    if hasQuestionSuffix(temp):
      tempStore = temp
      temp = fixQuestionSuffix(temp)
      if(tempStore == temp):
        break

    elif hasConjuctionSuffix(temp):
      tempStore = temp
      temp = fixConjuctionSuffix(temp)
      if(tempStore == temp):
        break

    elif hasCaseSuffix(temp):
      tempStore = temp
      temp = fixCaseSuffix(temp)
      if(tempStore == temp):
        break

    elif hasPluralSuffix(temp):
      tempStore = temp
      temp = fixPluralSuffix(temp)
      if(tempStore == temp):
        break

    elif hasImperativeSuffix(temp):
      tempStore = temp
      temp = fixImperativeSuffix(temp)
      if(tempStore == temp):
        break

    elif hasTenseSuffix(temp):
      tempStore = temp
      temp = fixTenseSuffix(temp)
      if(tempStore == temp):
        break
      

    elif hasCommonWordSuffix(temp):
      tempStore = temp
      temp = fixCommonWordSuffix(temp)
      if(tempStore == temp):
        break

    else:
      break
    
  return temp

# %%
#word = "அவனும்"
#word = "அவனா"
#word = "அவனோ"
#word = "அவன்"
#word = "மரங்கள்"
#word = "அரசனிடம்"
#word = "அவளை"
#word = "மரத்தை"
#word = "செய்வேன்"
#word = "பாடினேன்"
#word = "செய்வேன்"
#word = "சகுனி"
#word = "கொண்டிருக்கிறாள்"
#word = "படைத்து"
#word = "அடைந்து"
# word = "அரசனும்"
# word = "அவர்களின்" 
#word = "அவனில்லாத"
# word = "அமைந்த"
# word="என்னும்"
# word="இருந்து"
word="என்று"
print(list(word))
print("Final : ", stem(word))
# Out:
# ['எ', 'ன', '்', 'ற', 'ு']
# Final :  என்

# %%
print(ord('ஂ'), ord('்'))
# Out:
# 2946 3021

# %%
print(list(temp_d)[30:60])
print(len(list(temp_d)[30:60]))
print()

for i in list(temp_d)[30:60]:
  print(i, end=" ")
  print(stem(i))
  print()

# %%
collct = set()
n = len(word_index)
i = 0
stemmer = Stemmer.Stemmer('tamil')
for word in list(word_index):
  i += 1
  print("\r\b\b\b\b\b\b\b{:.3f}% {}/{}".format(i*100/n,i,n), end="")
  collct.add(stem(word))
print("\n", len(collct))
# Out:
# 100.000% 449239/449239
#  339123

# %%
arr = []
cols = ["original", "pystemmer", "custom", "normalized (smallest length)"]

n = len(word_index)
i = 0
stemmer = Stemmer.Stemmer('tamil')
for word in list(word_index):
  i += 1
  print("\r\b\b\b\b\b\b\b{:.3f}% {}/{}".format(i*100/n,i,n), end="")
  temp = [word, stemmer.stemWord(word), stem(word)]
  f1 = temp[1] if len(temp[1]) < len(temp[2]) else temp[2]
  f2 = temp[1] if len(temp[1]) >= len(temp[2]) else temp[2]
  if len(f1) <= 2:
    temp.append(f2)
  else:
    temp.append(f1)
  arr.append(temp)

df = pd.DataFrame(data = arr, columns = cols)
# Out:
# 100.000% 449239/449239

# %%
df.sample(30)
# Out:
#                         original  ... normalized (smallest length)
# 134715           பிடிக்கிறார்கள்  ...                         பிடி
# 362887                   பழக்கிய  ...                       பழக்கி
# 434192                 தங்கையராக  ...                     தங்கையர்
# 424333                    கோல்தர  ...                       கோல்தர
# 429916         எதைவேண்டுமானாலும்  ...                      எதைவேண்
# 438467        கோல்நிலைக்காதென்று  ...                     கோல்நிலை
# 341361                மீளும்போதே  ...                     மீளும்ப்
# 75578   மூன்றுமாதங்களுக்குப்பின்  ...               மூன்றுமாதங்கள்
# 2338                  ஒருமுறைகூட  ...                   ஒருமுறைகூட
# 231324             செய்திகளைதானே  ...                    செய்திகளை
# 270071               நடுக்கம்கூட  ...                  நடுக்கம்கூட
# 308384        புழுதியாலானதுபோன்ற  ...           புழுதியாலானதுபோன்ற
# 432303           விரைவுகுறைந்தது  ...                   விரைவுகுற்
# 245944               நிமிரலாகாது  ...                    நிமிரலாக்
# 304893        அரசியாகவேண்டுமென்ற  ...           அரசியாகவேண்டுமென்ற
# 29635             வந்திறங்கினார்  ...                   வந்திறங்கி
# 46297                     துணைப்  ...                         துணை
# 38788          வேதச்சொல்லெடுத்து  ...                  வேதச்சொல்லெ
# 243007                கொம்பரக்கை  ...                       கொம்பர
# 337496                 நுரைபோலப்  ...                      நுரைபோல
# 257422             அச்சிறுமதியள்  ...                   சிறுமதியள்
# 300910    உணரத்தொடங்கியிருந்தனர்  ...                   உணரத்தொடங்
# 65042                திறந்திட்டு  ...                    திறந்திட்
# 289975            மங்கலத்தாசிகள்  ...                        மங்கல
# 378625                   குனிலன்  ...                      குனிலன்
# 379349        உலையத்தொடங்கியதும்  ...                உலையத்தொடங்கி
# 24177                 சம்படையின்  ...                       சம்படை
# 371808                  துயிலல்ல  ...                         துய்
# 305728        வெள்ளிக்குழந்தைகளை  ...                  வெள்ளிக்குழ
# 229826            கங்கர்மொழியில்  ...                   கங்கர்மொழி
#
# [30 rows x 4 columns]

# %%
# !rm -rf tamil-stemmer/
